# %% [markdown]
# # Nonlinear Least Squares Problems Analysis ($n>m$ case)

# %%
from experiments import *
from visualization import *
import inspect
import optimization_project.problems.underdetermined as underdetermined_problems_module
import optimization_project.problems.underdetermined.problems as underdetermined_module

# %%
problems = [
    cls() for name, cls in inspect.getmembers(underdetermined_problems_module, inspect.isclass)
    if name.endswith("Problem") and name != "Problem"
]

# %% [markdown]
# ## Overall Results

# %%
df_results = benchmark_methods(problems)
# Out:
#  ---- Running problem: ChainedRosenbrock_200x5
# Method 'lm' doesn't work when the number of residuals is less than the number of variables. Use 'trf' instead.
#
#  ---- Running problem: DiscreteBVP_200x5
# Method 'lm' doesn't work when the number of residuals is less than the number of variables. Use 'trf' instead.
#
#  ---- Running problem: ExtendedCraggLevy_200x5
# Method 'lm' doesn't work when the number of residuals is less than the number of variables. Use 'trf' instead.
#
#  ---- Running problem: TridiagonalExponential_200x5
# Method 'lm' doesn't work when the number of residuals is less than the number of variables. Use 'trf' instead.
#
#  ---- Running problem: TridiagonalSystem_200x5
# Method 'lm' doesn't work when the number of residuals is less than the number of variables. Use 'trf' instead.
#
#  ---- Running problem: TrigExp1_200x5
# Method 'lm' doesn't work when the number of residuals is less than the number of variables. Use 'trf' instead.

# %%
df_results
# Out:
#                          problem difficulty classification_model  \
# 0        ChainedRosenbrock_200x5        N/A                  N/A
# 1        ChainedRosenbrock_200x5        N/A                  N/A
# 2              DiscreteBVP_200x5        N/A                  N/A
# 3              DiscreteBVP_200x5        N/A                  N/A
# 4        ExtendedCraggLevy_200x5        N/A                  N/A
# 5        ExtendedCraggLevy_200x5        N/A                  N/A
# 6   TridiagonalExponential_200x5        N/A                  N/A
# 7   TridiagonalExponential_200x5        N/A                  N/A
# 8        TridiagonalSystem_200x5        N/A                  N/A
# 9        TridiagonalSystem_200x5        N/A                  N/A
# 10                TrigExp1_200x5        N/A                  N/A
# 11                TrigExp1_200x5        N/A                  N/A
#
#           structure      method                     start_name  success  \
# 0   Underdetermined  ModifiedGN  Luksan Standard Start (n=200)     True
# 1   Underdetermined      LM-trf  Luksan Standard Start (n=200)     True
# 2   Underdetermined  ModifiedGN  Luksan Standard Start (n=200)     True
# 3   Underdetermined      LM-trf  Luksan Standard Start (n=200)     True
# 4   Underdetermined  ModifiedGN  Luksan Standard Start (n=200)     True
# 5   Underdetermined      LM-trf  Luksan Standard Start (n=200)     True
# 6   Underdetermined  ModifiedGN  Luksan Standard Start (n=200)     True
# 7   Underdetermined      LM-trf  Luksan Standard Start (n=200)     True
# 8   Underdetermined  ModifiedGN  Luksan Standard Start (n=200)     True
# 9   Underdetermined      LM-trf  Luksan Standard Start (n=200)     True
# 10  Underdetermined  ModifiedGN  Luksan Standard Start (n=200)    False
# 11  Underdetermined      LM-trf  Luksan Standard Start (n=200)     True
#
#     iterations     final_rss  parameter_error  relative_parameter_error  \
# 0           26  0.000000e+00              NaN                       NaN
# 1           37  2.132833e-11              NaN                       NaN
# 2            3  8.628166e-32              NaN                       NaN
# 3           22  5.142536e-13              NaN                       NaN
# 4           15  1.617916e-14              NaN                       NaN
# 5           21  1.927210e-09              NaN                       NaN
# 6            5  3.106140e-29              NaN                       NaN
# 7           31  1.775436e-12              NaN                       NaN
# 8           41  5.427541e-26              NaN                       NaN
# 9           38  5.553511e-11              NaN                       NaN
# 10         100  1.417269e+01              NaN                       NaN
# 11          32  6.650641e-12              NaN                       NaN
#
#     rss_error  relative_rss_error  gradient_norm
# 0         NaN                 NaN   0.000000e+00
# 1         NaN                 NaN   1.246929e-06
# 2         NaN                 NaN   6.181534e-16
# 3         NaN                 NaN   2.595570e-07
# 4         NaN                 NaN   3.841060e-11
# 5         NaN                 NaN   4.982149e-07
# 6         NaN                 NaN   7.428740e-14
# 7         NaN                 NaN   9.437034e-07
# 8         NaN                 NaN   1.397195e-10
# 9         NaN                 NaN   1.170214e-05
# 10        NaN                 NaN   1.397767e-04
# 11        NaN                 NaN   2.568968e-05

# %% [markdown]
# ## Convergence plots

# %%
n = [60, 200, 500, 800, 1000]
m = [10, 30, 50, 75, 100]

for name, cls in inspect.getmembers(underdetermined_module, inspect.isclass):
    if cls.__module__ == underdetermined_module.__name__ and name != "Problem":
        plot_convergence_grid_5x5(cls, n, m, method_palette)
# Out:
# Initializing enhanced 5x5 convergence matrix for ChainedRosenbrockProblem...
# Processing matrix row 1/5 (n = 60)...
# Processing matrix row 2/5 (n = 200)...
# Processing matrix row 3/5 (n = 500)...
# Processing matrix row 4/5 (n = 800)...
# Processing matrix row 5/5 (n = 1000)...
# Initializing enhanced 5x5 convergence matrix for DiscreteBoundaryValueProblem...
# Processing matrix row 1/5 (n = 60)...
# Processing matrix row 2/5 (n = 200)...
# Processing matrix row 3/5 (n = 500)...
# Processing matrix row 4/5 (n = 800)...
# Processing matrix row 5/5 (n = 1000)...
# Initializing enhanced 5x5 convergence matrix for ExtendedCraggLevyProblem...
# Processing matrix row 1/5 (n = 60)...
# Processing matrix row 2/5 (n = 200)...
# Processing matrix row 3/5 (n = 500)...
# Processing matrix row 4/5 (n = 800)...
# Processing matrix row 5/5 (n = 1000)...
# Initializing enhanced 5x5 convergence matrix for Problem23Rosenbrock...
# Processing matrix row 1/5 (n = 60)...
# Processing matrix row 2/5 (n = 200)...
# Processing matrix row 3/5 (n = 500)...
# Processing matrix row 4/5 (n = 800)...
# Processing matrix row 5/5 (n = 1000)...
# Initializing enhanced 5x5 convergence matrix for Problem46Luksan...
# Processing matrix row 1/5 (n = 60)...
# Processing matrix row 2/5 (n = 200)...
# Processing matrix row 3/5 (n = 500)...
# Processing matrix row 4/5 (n = 800)...
# Processing matrix row 5/5 (n = 1000)...
# Initializing enhanced 5x5 convergence matrix for TridiagonalExponentialProblem...
# Processing matrix row 1/5 (n = 60)...
# Processing matrix row 2/5 (n = 200)...
# Processing matrix row 3/5 (n = 500)...
# Processing matrix row 4/5 (n = 800)...
# Processing matrix row 5/5 (n = 1000)...
# Initializing enhanced 5x5 convergence matrix for TridiagonalSystemProblem...
# Processing matrix row 1/5 (n = 60)...
# Processing matrix row 2/5 (n = 200)...
# Processing matrix row 3/5 (n = 500)...
# Processing matrix row 4/5 (n = 800)...
# Processing matrix row 5/5 (n = 1000)...
# Initializing enhanced 5x5 convergence matrix for TrigonometricExponentialProblem...
# Processing matrix row 1/5 (n = 60)...
# Processing matrix row 2/5 (n = 200)...
# Processing matrix row 3/5 (n = 500)...
# Processing matrix row 4/5 (n = 800)...
# Processing matrix row 5/5 (n = 1000)...
